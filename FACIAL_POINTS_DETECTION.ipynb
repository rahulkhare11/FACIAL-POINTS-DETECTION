# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import dlib

# Load the detector
detector = dlib.get_frontal_face_detector()

# read the image
img = cv2.imread(r"/content/drive/MyDrive/akshay-kumar-oh-my-god-2.jpg")

# Convert image into grayscale
gray = cv2.cvtColor(src=img, code=cv2.COLOR_BGR2GRAY)

# Use detector to find landmarks
faces = detector(gray)

for face in faces:
    x1 = face.left() # left point
    y1 = face.top() # top point
    x2 = face.right() # right point
    y2 = face.bottom() # bottom point
    # Draw a rectangle
    cv2.rectangle(img=img, pt1=(x1, y1), pt2=(x2, y2), color=(0, 255, 0), thickness=4)

# show the image
# cv2.imshow(winname="Face", mat=img)
from google.colab.patches import cv2_imshow

# Wait for a key press to exit
cv2.waitKey(delay=0)

# Close all windows
cv2.destroyAllWindows()

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x900 at 0x7F0780EA9B90>

# %%
# !wget   http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2 # DOWNLOAD LINK
# Out:
# --2022-01-22 13:02:56--  http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64040097 (61M)
# Saving to: ‘shape_predictor_68_face_landmarks.dat.bz2’
#
# shape_predictor_68_ 100%[===================>]  61.07M  29.0MB/s    in 2.1s
#
# 2022-01-22 13:02:58 (29.0 MB/s) - ‘shape_predictor_68_face_landmarks.dat.bz2’ saved [64040097/64040097]

# %%
# !bunzip2 /content/shape_predictor_68_face_landmarks.dat.bz2

# %%
import cv2
import numpy as np
import dlib

# Load the detector
detector = dlib.get_frontal_face_detector()

predictor = dlib.shape_predictor(r"/content/shape_predictor_68_face_landmarks.dat")

# read the image
img = cv2.imread(r"/content/drive/MyDrive/akshay-kumar-oh-my-god-2.jpg")


# Convert image into grayscale
gray = cv2.cvtColor(src=img, code=cv2.COLOR_BGR2GRAY)

# Use detector to find landmarks
faces = detector(gray)
for face in faces:
    x1 = face.left() # left point
    y1 = face.top() # top point
    x2 = face.right() # right point
    y2 = face.bottom() # bottom point

    # Create landmark object
    landmarks = predictor(image=gray, box=face)

    # Loop through all the points
    for n in range(0,68):
        x = landmarks.part(n).x
        y = landmarks.part(n).y
        print(x,y)
        # Draw a circle
        cv2.circle(img=img, center=(x, y), radius=5, color=(0, 0, 255), thickness=-1)
    
    
    # for n in [8,62,27,19,24]:
    #     x = landmarks.part(n).x
    #     y = landmarks.part(n).y
    #     print(x,y)
    #     # if n == 27:
    #       # cv2.circle(img=img, center=(x, y), radius=4, color=(255, 0, 0), thickness=-1)
    #     # Draw a circle
    #     cv2.circle(img=img, center=(x, y), radius=4, color=(0, 0, 255), thickness=-1)

# show the image
cv2.imwrite(r'/content/drive/MyDrive/facesoutput.jpg',img)

# Delay between every frame
cv2.waitKey(delay=0)

# Close all windows
cv2.destroyAllWindows()
# Out:
# 417 409
# 425 470
# 436 528
# 456 585
# 488 631
# 537 665
# 594 688
# 651 704
# 712 705
# 766 691
# 800 658
# 827 615
# 844 569
# 851 518
# 854 466
# 855 417
# 851 369
# 483 334
# 512 299
# 555 277
# 603 273
# 650 282
# 706 277
# 744 264
# 784 264
# 819 279
# 838 311
# 686 324
# 691 355
# 697 386
# 703 419
# 654 461
# 677 465
# 700 469
# 718 464
# 734 458
# 542 352
# 565 333
# 593 328
# 618 343
# 596 351
# 568 355
# 726 337
# 750 320
# 777 320
# 796 336
# 779 344
# 752 343
# 612 561
# 646 536
# 677 519
# 699 527
# 720 518
# 748 532
# 774 552
# 750 564
# 727 569
# 704 572
# 681 572
# 649 569
# 627 557
# 678 544
# 700 545
# 721 542
# 759 550
# 723 541
# 702 544
# 680 544

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x900 at 0x7F0774D88250>
